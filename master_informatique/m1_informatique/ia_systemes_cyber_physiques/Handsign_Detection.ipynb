# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import random 
import tensorflow as tf

# Ignorer les avertissements de type FutureWarning
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.model_selection import train_test_split
from tensorflow import keras
# Pour l'augmentation de données
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Pour construire un modèle CNN couche par couche
from tensorflow.keras.models import Sequential
# Différents types de couches nécessaires pour le modèle CNN
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
# Algorithme d'optimisation pour mettre à jour les poids du réseau pendant l'entraînement
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix

train_dir = 'Train' # Répertoire de formation
test_dir = 'Test' # Répertoire de test

# Obtenir la liste des répertoires de classes dans le répertoire de formation
class_directories = [os.path.join(train_dir, directory) for directory in sorted(os.listdir(train_dir))]

# Création de sous-graphiques pour afficher des exemples d'images
fig, axes = plt.subplots(3, 2, figsize=(10, 10))

# Parcourir les répertoires de classes
for idx, class_dir in enumerate(class_directories):
    image_files = os.listdir(class_dir)
    
    # Vérifier s'il y a au moins 6 images à échantillonner
    if len(image_files) >= 6:
        random_images = random.sample(image_files, 6)
    else:
        # S'il y a moins de 6 images, utiliser toutes les images disponibles
        random_images = image_files
    
    for i, image_file in enumerate(random_images):
        image_path = os.path.join(class_dir, image_file)
        image = plt.imread(image_path)
        axes[int(i / 2), i % 2].imshow(image)
        axes[int(i / 2), i % 2].axis('off')
        axes[int(i / 2), i % 2].set_title(os.path.basename(class_dir))
    if idx == 2: 
        break

plt.tight_layout()
plt.show()

# Générateur de données pour l'ensemble d'entraînement avec augmentation
Train_dgen = ImageDataGenerator(
    rescale=1./255,
    width_shift_range=0.1,
    validation_split=0.2)

# Générateur de données pour l'ensemble de test sans augmentation
Test_dgen = ImageDataGenerator(
    rescale=1./255)

# Générateur de données pour la formation
train_gen = Train_dgen.flow_from_directory(
    train_dir,
    target_size = (28, 28),
    batch_size = 64,
    color_mode='grayscale',
    class_mode = 'sparse',
    subset='training')

# Générateur de données pour la validation
valid_gen = Train_dgen.flow_from_directory(
    train_dir,
    target_size=(28,28),
    batch_size=64,
    color_mode='grayscale',
    class_mode='sparse',
    subset='validation')

# Générateur de données pour le test
test_gen = Test_dgen.flow_from_directory(
    test_dir,
    target_size=(28,28),
    batch_size=64,
    class_mode='sparse',
    color_mode='grayscale')

# Définition du modèle séquentiel CNN
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation ='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3), activation ='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(24, activation='softmax')])

model.summary() # Afficher le résumé du modèle

metrics = ['accuracy'] # Définir la métrique pour évaluer le modèle

model.compile(
    optimizer=Adam(learning_rate=0.001),  
    loss='sparse_categorical_crossentropy',
    metrics=metrics)

# Entraînement du modèle
history = model.fit(
    train_gen,
    epochs=10,
    validation_data = valid_gen)

# Évaluation du modèle sur l'ensemble de test
predics = model.evaluate(test_gen)
# Out:
# Found 21975 images belonging to 24 classes.
# Found 5481 images belonging to 24 classes.
# Found 7172 images belonging to 24 classes.
# Class Indices (Training): {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'K': 9, 'L': 10, 'M': 11, 'N': 12, 'O': 13, 'P': 14, 'Q': 15, 'R': 16, 'S': 17, 'T': 18, 'U': 19, 'V': 20, 'W': 21, 'X': 22, 'Y': 23}
# Class Indices (Validation): {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'K': 9, 'L': 10, 'M': 11, 'N': 12, 'O': 13, 'P': 14, 'Q': 15, 'R': 16, 'S': 17, 'T': 18, 'U': 19, 'V': 20, 'W': 21, 'X': 22, 'Y': 23}
# C:\Users\utilisateur\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         409,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 24)                  │           6,168 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 500,632 (1.91 MB)
#  Trainable params: 500,632 (1.91 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# C:\Users\utilisateur\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 70s 199ms/step - accuracy: 0.3447 - loss: 2.1700 - val_accuracy: 0.8391 - val_loss: 0.5032
# Epoch 2/10
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.8857 - loss: 0.3572 - val_accuracy: 0.9624 - val_loss: 0.1400
# Epoch 3/10
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.9646 - loss: 0.1225 - val_accuracy: 0.9839 - val_loss: 0.0609
# Epoch 4/10
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.9856 - loss: 0.0523 - val_accuracy: 0.9954 - val_loss: 0.0249
# Epoch 5/10
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.9936 - loss: 0.0259 - val_accuracy: 0.9974 - val_loss: 0.0134
# Epoch 6/10
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.9919 - loss: 0.0254 - val_accuracy: 0.9909 - val_loss: 0.0272
# Epoch 7/10
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.9963 - loss: 0.0131 - val_accuracy: 0.9940 - val_loss: 0.0221
# Epoch 8/10
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.9943 - loss: 0.0218 - val_accuracy: 0.9993 - val_loss: 0.0041
# Epoch 9/10
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.9991 - loss: 0.0044 - val_accuracy: 0.9922 - val_loss: 0.0328
# Epoch 10/10
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.9978 - loss: 0.0076 - val_accuracy: 0.9854 - val_loss: 0.0474
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 22s 199ms/step - accuracy: 0.9375 - loss: 0.3049
